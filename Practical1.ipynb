# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder
import pandas as pd
from numpy.linalg import lstsq

# %%
df = pd.read_csv("./dataset/All_India_Index_july2019_20Aug2020.csv")
df = df[(df.Year != 2020)]
df = df.groupby(['Year'], as_index=False).mean()
df
# Out:
#    Year    Sno  Cereals and products  Meat and fish         Egg  \
# 0  2013   18.5            114.516667     113.969444  112.441667
# 1  2014   54.5            122.052778     122.383333  119.272222
# 2  2015   90.5            124.105556     128.997222  119.633333
# 3  2016  126.5            128.222222     137.863889  129.097222
# 4  2017  162.5            133.841667     141.977778  131.600000
# 5  2018  198.5            136.947222     146.611111  137.286111
# 6  2019  233.0            140.109091     158.851515  141.524242
#
#    Milk and products  Oils and fats      Fruits  Vegetables  \
# 0         108.302778     104.755556  108.827778  135.338889
# 1         119.861111     106.908333  124.766667  139.547222
# 2         127.613889     110.563889  129.441667  144.155556
# 3         132.513889     115.466667  132.975000  145.155556
# 4         138.161111     118.130556  139.772222  144.694444
# 5         141.761111     120.677778  146.819444  144.083333
# 6         144.284848     122.542424  144.654545  165.324242
#
#    Pulses and products  ...     Housing  Fuel and light  \
# 0           106.275000  ...  105.608333      108.544444
# 1           113.197222  ...  114.675000      113.355556
# 2           143.269444  ...  120.158333      119.022222
# 3           172.258333  ...  126.475000      122.575000
# 4           137.244444  ...  133.675000      129.280556
# 5           121.080556  ...  143.816667      138.297222
# 6           128.460606  ...  150.763636      138.775758
#
#    Household goods and services      Health  Transport and communication  \
# 0                    108.005556  106.766667                   106.666667
# 1                    114.900000  112.497222                   111.516667
# 2                    121.013889  118.213889                   111.158333
# 3                    126.575000  123.900000                   113.469444
# 4                    131.694444  128.938889                   117.430556
# 5                    138.358333  137.005556                   123.336111
# 6                    144.136364  146.924242                   125.787879
#
#    Recreation and amusement   Education  Personal care and effects  \
# 0                105.916667  107.688889                 104.986111
# 1                111.877778  115.469444                 109.144444
# 2                117.105556  123.108333                 112.413889
# 3                122.247222  129.897222                 119.513889
# 4                126.836111  136.186111                 124.027778
# 5                133.355556  144.036111                 129.850000
# 6                140.424242  153.742424                 136.518182
#
#    Miscellaneous  General index
# 0     106.763889     110.013889
# 1     112.536111     117.327778
# 2     116.416667     123.036111
# 3     121.369444     129.100000
# 4     126.200000     133.386111
# 5     132.950000     138.669444
# 6     139.372727     144.127273
#
# [7 rows x 29 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 29 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Year                                 7 non-null      int64
#  1   Sno                                  7 non-null      float64
#  2   Cereals and products                 7 non-null      float64
#  3   Meat and fish                        7 non-null      float64
#  4   Egg                                  7 non-null      float64
#  5   Milk and products                    7 non-null      float64
#  6   Oils and fats                        7 non-null      float64
#  7   Fruits                               7 non-null      float64
#  8   Vegetables                           7 non-null      float64
#  9   Pulses and products                  7 non-null      float64
#  10  Sugar and Confectionery              7 non-null      float64
#  11  Spices                               7 non-null      float64
#  12  Non-alcoholic beverages              7 non-null      float64
#  13  Prepared meals, snacks, sweets etc.  7 non-null      float64
#  14  Food and beverages                   7 non-null      float64
#  15  Pan, tobacco and intoxicants         7 non-null      float64
#  16  Clothing                             7 non-null      float64
#  17  Footwear                             7 non-null      float64
#  18  Clothing and footwear                7 non-null      float64
#  19  Housing                              7 non-null      float64
#  20  Fuel and light                       7 non-null      float64
#  21  Household goods and services         7 non-null      float64
#  22  Health                               7 non-null      float64
#  23  Transport and communication          7 non-null      float64
#  24  Recreation and amusement             7 non-null      float64
#  25  Education                            7 non-null      float64
#  26  Personal care and effects            7 non-null      float64
#  27  Miscellaneous                        7 non-null      float64
#  28  General index                        7 non-null      float64
# dtypes: float64(28), int64(1)
# memory usage: 1.7 KB

# %%
df.describe()
# Out:
#               Year         Sno  Cereals and products  Meat and fish  \
# count     7.000000    7.000000              7.000000       7.000000
# mean   2016.000000  126.285714            128.542172     135.807756
# std       2.160247   77.423003              9.047431      15.239939
# min    2013.000000   18.500000            114.516667     113.969444
# 25%    2014.500000   72.500000            123.079167     125.690278
# 50%    2016.000000  126.500000            128.222222     137.863889
# 75%    2017.500000  180.500000            135.394444     144.294444
# max    2019.000000  233.000000            140.109091     158.851515
#
#               Egg  Milk and products  Oils and fats      Fruits  Vegetables  \
# count    7.000000           7.000000       7.000000    7.000000    7.000000
# mean   127.264971         130.356962     114.149315  132.465332  145.471320
# std     10.549534          12.869033       6.882110   13.136551    9.453929
# min    112.441667         108.302778     104.755556  108.827778  135.338889
# 25%    119.452778         123.737500     108.736111  127.104167  141.815278
# 50%    129.097222         132.513889     115.466667  132.975000  144.155556
# 75%    134.443056         139.961111     119.404167  142.213384  144.925000
# max    141.524242         144.284848     122.542424  146.819444  165.324242
#
#        Pulses and products  ...     Housing  Fuel and light  \
# count             7.000000  ...    7.000000        7.000000
# mean            131.683658  ...  127.881710      124.264394
# std              22.066638  ...   16.037547       11.755253
# min             106.275000  ...  105.608333      108.544444
# 25%             117.138889  ...  117.416667      116.188889
# 50%             128.460606  ...  126.475000      122.575000
# 75%             140.256944  ...  138.745833      133.788889
# max             172.258333  ...  150.763636      138.775758
#
#        Household goods and services      Health  Transport and communication  \
# count                      7.000000    7.000000                     7.000000
# mean                     126.383369  124.892352                   115.623665
# std                       12.814419   14.001635                     6.924991
# min                      108.005556  106.766667                   106.666667
# 25%                      117.956944  115.355556                   111.337500
# 50%                      126.575000  123.900000                   113.469444
# 75%                      135.026389  132.972222                   120.383333
# max                      144.136364  146.924242                   125.787879
#
#        Recreation and amusement   Education  Personal care and effects  \
# count                  7.000000    7.000000                   7.000000
# mean                 122.537590  130.018362                 119.493470
# std                   12.075568   16.100772                  11.440754
# min                  105.916667  107.688889                 104.986111
# 25%                  114.491667  119.288889                 110.779167
# 50%                  122.247222  129.897222                 119.513889
# 75%                  130.095833  140.111111                 126.938889
# max                  140.424242  153.742424                 136.518182
#
#        Miscellaneous  General index
# count       7.000000       7.000000
# mean      122.229834     127.951515
# std        11.491010      12.015035
# min       106.763889     110.013889
# 25%       114.476389     120.181944
# 50%       121.369444     129.100000
# 75%       129.575000     136.027778
# max       139.372727     144.127273
#
# [8 rows x 29 columns]

# %%
x = df.Year
x = [[i] for i in list(x)]
y = df.Education
y = [[i] for i in list(y)]

model = LinearRegression()
model.fit(x, y)
plt.rcParams["figure.figsize"] = (10,5)
plt.plot(x, y, '.')
plt.plot(x, model.predict(x), '--')
plt.xlabel('Year')
plt.ylabel('Avg. CPI of Education')
plt.title("Avg. CPI of Education in India from 2013 - 2019")
plt.grid(True)
plt.show()

# %%
year = int(input("Enter year: "))
print(f"Predicted avg. CPI of education at { year }: { round(model.predict([[year]])[0][0], 2) }")
# Out:
# Predicted avg. CPI of education at 2020: 159.79

# %%
r2_model = LinearRegression()
r2_model.fit(x[:4], y[:4])
print(f"R2 Score: { r2_model.score(x[4:], y[4:]) }")
# Out:
# R2 Score: 0.9698839423331803

# %%
year = list(df.Year)
health = list(df.Health)
x = list()

for i in range(len(year)):
    x.append([year[i], health[i]])

mult_reg_model = LinearRegression()
mult_reg_model.fit(x, y)
mult_reg_model.predict([[2020, 150]])
# Out:
# array([[159.48773303]])
